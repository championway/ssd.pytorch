# %%
import xml.etree.ElementTree as ET
import os.path as osp
import os
import random

# %%
f_path = '/media/arg_ws3/5E703E3A703E18EB/data/VOCdevkit/VOC2007/ImageSets/Main/person_train.txt'
for line in open(osp.join(f_path)):
    check_exist = line.strip().split(' ')[-1]
    if check_exist != '-1':
        print(line.strip().split(' ')[0])
# Out:
# 000017
# 000023
# 000032
# 000035
# 000048
# 000066
# 000073
# 000083
# 000089
# 000104
# 000129
# 000133
# 000138
# 000159
# 000162
# 000163
# 000164
# 000171
# 000173
# 000174
# 000192
# 000193
# 000194
# 000200
# 000220
# 000222
# 000259
# 000276
# 000278
# 000282
# 000288
# 000320
# 000331
# 000337
# 000359
# 000367
# 000372
# 000382
# 000394
# 000406
# 000407
# 000411
# 000438
# 000446
# 000463
# 000468
# 000470
# 000476
# 000477
# 000516
# 000518
# 000524
# 000525
# 000526
# 000535
# 000541
# 000554
# 000555
# 000583
# 000589
# 000597
# 000612
# 000625
# 000633
# 000648
# 000654
# 000688
# 000695
# 000709
# 000726
# 000731
# 000733
# 000739
# 000753
# 000770
# 000793
# 000805
# 000810
# 000812
# 000828
# 000829
# 000851
# 000859
# 000860
# 000865
# 000892
# 000898
# 000902
# 000904
# 000906
# 000915
# 000943
# 000966
# 000967
# 000987
# 000991
# 000996
# 000999
# 001001
# 001011
# 001014
# 001024
# 001036
# 001050
# 001057
# 001060
# 001064
# 001071
# 001079
# 001101
# 001113
# ...
